# %% [markdown]
# <a href="https://colab.research.google.com/github/wesleypsl/wesleypsl/blob/main/aula_colab_git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re
from transform
import torch
from skearn.cluster import Kmeans
